# %%
import networkx as nx
from copy import deepcopy
import json
import random
import numpy as np

# %%
with open("../test_data/toy-ppi-G.json") as src:
    data = json.load(src)
    j = nx.readwrite.json_graph.node_link_graph(data)

# %%
j.nodes[0]

# %%
val = 0
test = 0
tot = 0
for i in list(j.nodes):
    d = j.nodes[i]
    if d["test"] and d["val"]:
        print("whaa")
        break
    if d["test"]:
        test += 1
    elif d["val"]:
        val += 1
    tot += 1

# %%
print(tot)
print(val/tot)
print(test/tot)
# Out:
# 14755
# 0.12368688580142324
# 0.21782446628261606

# %%
with open("../scripts/test-G.json") as src:
    data = json.load(src)
    G = nx.readwrite.json_graph.node_link_graph(data)

# %%
g = nx.readwrite.read_gexf("../test_data/first_pass_split_0_train_with_pfams.gexf")

# %%
no_atts = deepcopy(g) #g.nodes["60687"]

# %%
id_map = dict()
class_map = dict()
for ix, node_id in enumerate(sorted(list(no_atts.nodes))):    
    id_map[node_id] = ix
    
with open("test-id_map.json", "w") as dest:
    json.dump(id_map, dest)

# %%
feat_arr = []
for ix, node_id in enumerate(sorted(list(no_atts.nodes))):    
    feat_arr.append(g.nodes[node_id]["family"])
np.save("test-feats.npy", np.array(feat_arr))

# %%
def bare_graph(orig_graph, retain_features=[]):
    graph = deepcopy(orig_graph)
    for node in list(graph.nodes):
        node = graph.nodes[node]
        for key in list(node.keys()):
            if key not in retain_features:
                del node[key]
    return graph

# %%
g_family = bare_graph(g, retain_features=["family"])

# %%
# with open("../test_data/test-families-only.gexf", "w") as dest:
nx.readwrite.write_gexf(g_family, "../test_data/test-families-only.gexf")

# %%
g_family.nodes["0"]
# Out:
# {'family': 'PF16450'}

# %%
nodes = list(no_atts.nodes)
random.seed(42)
random.shuffle(nodes)

val_percent = 10
test_percent = 20

num_records = len(nodes)

val_start = int(num_records * (1 - (val_percent + test_percent)/100))
test_start = int(num_records * (1 - test_percent/100))

for ix, node in enumerate(nodes):
#     no_atts[node] = {"val":False, "test":False}
    node = no_atts.nodes[node]
    keys = list(node.keys())
    for key in keys:
        if key not in ["val", "test"]:
            del node[key]
    if ix > test_start:
        node["test"] = True
        node["val"] = False
    elif ix > val_start:
        node["test"] = False
        node["val"] = True
    else:
        node["test"] = False
        node["val"] = False
    for att in ["viz", "position", "size"]:
        try:
            del node[att]
        except:
            pass
#     break
#     del node["viz"]    
#     del node["position"]    
#     del node["size"]

# %%
# with open("test-G.json", "w") as dest:
#     json.dump(nx.readwrite.json_graph.node_link_data(no_atts), dest)
nx.readwrite.write_gexf(no_atts, "test-G.gexf")

# %%
# with open("test-G.json", "w") as dest:
#     json.dump(nx.readwrite.json_graph.node_link_data(no_atts), dest)

# %%
test = nx.readwrite.json_graph.node_link_graph(json.load(open("test-G.json")))

# %%
nx.readwrite.json_graph.node_link_data(g)
# Out:
# {'directed': False,
#  'multigraph': False,
#  'graph': {'mode': 'static', 'node_default': {}, 'edge_default': {}},
#  'nodes': [{'diversity': 1.0,
#    'features': '{"info": {""1205674.3"": {""FO203509"": [{"start": 3246878, "end": 3247054, "md5": ""0f0ee7891b54d380987e091a38eae5d8""}]}}, ""1205674.3"": {""FO203509"": [""fig|1205674.3.peg.3610""]}}',
#    'family': '"PGF_03134289"',
#    'alternate': 0,
#    'conflict': 0,
#    'viz': {'color': {'r': 153, 'g': 153, 'b': 153, 'a': 1.0},
#     'size': 10.0,
#     'position': {'x':
',
#    'alternate': 0,
#    'conflict': 0,
#    'viz': {'color': {'r': 153, 'g': 153, 'b': 153, 'a': 1.0},
#     'size': 10.0,
#     'position': {'x': -416.52777, 'y': 325.05673, 'z': 0.0}},
#    'label': '"hypothetical protein"',
#    'id': '87833'},
#   {'diversity': 1.0,
#    'features': '{"info": {""710686.3"": {""CP003078"": [{"start": 2072712, "end": 2073071, "md5": ""3f53704cc7f20f2f4fb460194f356842""}]}}, ""710686.3"": {""CP003078"": [""fig|710686.3.peg.2114""]}}',
#    'family': 'PF00501',
#    'alternate': 0,
#    'conflict': 0,
#    'viz': {'color': {'r': 153, 'g': 153, 'b': 153, 'a': 1.0},
#     'size': 10.0,
#     'position': {'x': 426.61343, 'y': -95.71365, 'z': 0.0}},
#    'label': '"Long-chain-fatty-acid--CoA ligase (EC 6.2.1.3)"',
#    'id': '98201'},
#   {'diversity': 1.0,
#    'features': '{"info": {""710686.3"": {""CP003078"": [{"start": 2074922, "end": 2075171, "md5": ""58172142b4eea296347a2229b67c0d20""}]}}, ""710686.3"": {""CP003078"": [""fig|710686.3.peg.2116""]}}',
#    'family': 'PF00378',
#    'alternate': 0,
#    'conflict': 0,
#    'viz': {'color': {'r': 153, 'g': 153, 'b': 153, 'a': 1.0},
#     'size': 10.0,
#     'position': {'x': -222.8334, 'y': 23.552294, 'z': 0.0}},
#    'label': '"Enoyl-CoA hydratase (EC 4.2.1.17)"',
#    'id': '98205'},
#   {'diversity': 1.0,
#    'features': '{"info": {""710686.3"": {""CP003078"": [{"start": 4953646, "end": 4953718, "md5": ""d9acfc5e0666886e918870fa2dcc84e6""}]}}, ""710686.3"": {""CP003078"": [""fig|710686.3.peg.5042""]}}',
#    'family': 'PF02470',
#    'alternate': 0,
#    'conflict': 0,
#    'viz': {'color': {'r': 153, 'g': 153, 'b': 153, 'a': 1.0},
#     'size': 10.0,
#     'position': {'x': -266.3656, 'y': -123.47527, 'z': 0.0}},
#    'label': '"MCE-family protein MceD"',
#    'id': '101654'},
#   {'diversity': 1.0,
#    'features': '{"info": {""120959.23"": {""CP045078"": [{"start": 30059, "end": 34450, "md5": ""8ac13710fc0e3881f5a83604c87a92d4""}]}}, ""120959.23"": {""CP045078"": [""fig|120959.23.peg.6161""]}}',
#    'family': '"PGF_08225224"',
#    'alternate': 0,
#    'conflict': 0,
#    'viz': {'color': {'r': 153, 'g': 153, 'b': 153, 'a': 1.0},
#     'size': 10.0,
#     'position': {'x': 487.79688, 'y': 296.55164, 'z': 0.0}},
#    'label': '"hypothetical protein"',
#    'id': '112103'},
#   {'diversity': 1.0,
#    'features': '{"info": {""560555.10"": {""AP022590"": [{"start": 20832, "end": 21005, "md5": ""189f56b4ffe3d6b875d034614d25694f""}]}}, ""560555.10"": {""AP022590"": [""fig|560555.10.peg.34""]}}',
#    'family': '"PGF_07509044"',
#    'alternate': 0,
#    'conflict': 0,
#    'viz': {'color': {'r': 153, 'g': 153, 'b': 153, 'a': 1.0},
#     'size': 10.0,
#     'position': {'x': -290.2026, 'y': -209.0494, 'z': 0.0}},
#    'label': '"hypothetical protein"',
#    'id': '115467'},
#   {'diversity': 1.0,
#    'features': '{"info": {""39689.5"": {""AP022602"": [{"start": 189757, "end": 190602, "md5": ""6a9495cbb6c57647fe0f791ca7f589ac""}]}}, ""39689.5"": {""AP022602"": [""fig|39689.5.peg.6268""]}}',
#    'family': '"PGF_01000105"',
#    'alternate': 0,
#    'conflict': 0,
#    'viz': {'color': {'r': 153, 'g': 153, 'b': 153, 'a': 1.0},
#     'size': 10.0,
#     'position': {'x': 167.06601, 'y': 321.8158, 'z': 0.0}},
#    'label': '"Mobile element protein"',
#    'id': '129965'},
#   {'diversity': 1.0,
#    'features': '{"info": {""1775.8"": {""AP022569"": [{"start": 11906, "end": 12229, "md5": ""7fb5515a35fdef88382bf8d6a4c281e9""}]}}, ""1775.8"": {""AP022569"": [""fig|1775.8.peg.17""]}}',
#    'family': '"PGF_06614457"',
#    'alternate': 0,
#    'conflict': 0,
#    'viz': {'color': {'r': 153, 'g': 153, 'b': 153, 'a': 1.0},
#     'size': 10.0,
#     'position': {'x': 319.60583, 'y': -205.4058, 'z': 0.0}},
#    'label': '"Ammonium transporter"',
#    'id': '72927'},
#   {'diversity': 1.0,
#    'features': '{"info": {""39689.5"": {""AP022602"": [{"start": 16646, "end": 16897, "md5": ""c7f11a2e10e40600499e4e90c00a2614""}]}}, ""39689.5"": {""AP022602"": [""fig|39689.5.peg.6098""]}}',
#    'family': '"PGF_00008381"',
#    'alternate': 0,
#    'conflict': 0,
#    'viz': {'color': {'r': 153, 'g': 153, 'b': 153, 'a': 1.0},
#     'size': 10.0,
#     'position': {'x': -388.84857, 'y': -443.7342, 'z': 0.0}},
#    'label': '"Glutaredoxin-like protein NrdH, required for reduction of Ribonucleotide reductase class Ib"',
#    'id': '129885'},
#   {'diversity': 1.0,
#    'features': '{"info": {""560555.10"": {""AP022590"": [{"start": 2950729, "end": 2950826, "md5": ""9cb0d14fb4cff42a24fce08eb4bf9aa0""}]}}, ""560555.10"": {""AP022590"": [""fig|560555.10.peg.2757""]}}',
#    'family': 'PF00011',
#    'alternate': 0,
#    'conflict': 0,
#    'viz': {'color': {'r': 153, 'g': 153, 'b': 153, 'a': 1.0},
#     'size': 10.0,
#     'position': {'x': 79.47655, 'y': 9.206345, 'z': 0.0}},
#    'label': '"14 kDa antigen (16 kDa antigen) (HSP 16.3)"',
#    'id': '116430'},
#   {'diversity': 1.0,
#    'features': '{"info": {""189918.11"": {""NC_008705"": [{"start": 1841235, "end": 1841939, "md5": ""dda1c00c10237d4dc6488fd0478a4086""}]}}, ""189918.11"": {""NC_008705"": [""fig|189918.11.peg.2224""]}}',
#    'family': '"PGF_08238312"',
#    'alternate': 0,
#    'conflict': 0,
#    'viz': {'color': {'r': 153, 'g': 153, 'b': 153, 'a': 1.0},
#     'size': 10.0,
#     'position': {'x': 145.34418, 'y': 332.83524, 'z': 0.0}},
#    'label': '"Transcriptional regulator, IclR family"',
#    'id': '123794'},
#   {'diversity': 1.0,
#    'features': '{""470076.10"": {""AP022587"": [""fig|470076.10.peg.20""]}, "info": {""470076.10"": {""AP022587"": [{"start": 10903, "end": 11094, "md5": ""31a3727c6d2b9fc078407f3424786159""}]}}}',
#    'family': '"PGF_00855579"',
#    'alternate': 0,
#    'conflict': 0,
#    'viz': {'color': {'r': 153, 'g': 153, 'b': 153, 'a': 1.0},
#     'size': 10.0,
#     'position': {'x': 95.26832, 'y': -481.1314, 'z': 0.0}},
#    'label': '"putative membrane protein"',
#    'id': '56103'},
#   {'diversity': 1.0,
#    'features': '{""470076.10"": {""AP022587"": [""fig|470076.10.peg.22""]}, "info": {""470076.10"": {""AP022587"": [{"start": 11622, "end": 12632, "md5": ""433b0c4b7fa0948e07414475db50d0a2""}]}}}',
#    'family': '"PGF_08262214"',
#    'alternate': 0,
#    'conflict': 0,
#    'viz': {'color': {'r': 153, 'g': 153, 'b': 153, 'a': 1.0},
#     'size': 10.0,
#     'position': {'x': 141.21098, 'y': -504.86572, 'z': 0.0}},
#    'label': '"3-ketoacyl-CoA thiolase (EC 2.3.1.16) @ Acetyl-CoA acetyltransferase (EC 2.3.1.9)"',
#    'id': '56104'},
#   {'diversity': 1.0,
#    'features': '{""470076.10"": {""AP022587"": [""fig|470076.10.peg.23""]}, "info": {""470076.10"": {""AP022587"": [{"start": 12584, "end": 12796, "md5": ""ee01a4be2dbfde789fa93908192f1a17""}]}}}',
#    'family': '"PGF_08262214"',
#    'alternate': 0,
#    'conflict': 0,
#    'viz': {'color': {'r': 153, 'g': 153, 'b': 153, 'a': 1.0},
#     'size': 10.0,
#     'position': {'x': 95.55324, 'y': -501.34766, 'z': 0.0}},
#    'label': '"3-ketoacyl-CoA thiolase (EC 2.3.1.16) @ Acetyl-CoA acetyltransferase (EC 2.3.1.9)"',
#    'id': '56105'},
#   {'diversity': 1.0,
#    'features': '{""470076.10"": {""AP022587"": [""fig|470076.10.peg.25""]}, "info": {""470076.10"": {""AP022587"": [{"start": 13310, "end": 14101, "md5": ""ea2f62c82de780153aaff8814d32c39e""}]}}}',
#    'family': '"PGF_03274092"',
#    'alternate': 0,
#    'conflict': 0,
#    'viz': {'color': {'r': 153, 'g': 153, 'b': 153, 'a': 1.0},
#     'size': 10.0,
#     'position': {'x': 129.85402, 'y': -490.8222, 'z': 0.0}},
#    'label': '"Transposase and inactivated derivatives, IS30 family"',
#    'id': '56106'},
#   {'diversity': 1.0,
#    'features': '{"info": {""1205674.3"": {""FO203509"": [{"start": 3248370, "end": 3248483, "md5": ""92c832a15e3597853f45278e614d9beb""}]}}, ""1205674.3"": {""FO203509"": [""fig|1205674.3.peg.3612""]}}',
#    'family': '"PGF_08028395"',
#    'alternate': 0,
#    'conflict': 0,
#    'viz': {'color': {'r': 153, 'g': 153, 'b': 153, 'a': 1.0},
#     'size': 10.0,
#     'position': {'x': -318.00626, 'y': 296.86633, 'z': 0.0}},
#    'label': '"hypothetical protein"',
#    'id': '60685'},
#   {'diversity': 1.0,
#    'features': '{"info": {""1205674.3"": {""FO203509"": [{"start": 3247228, "end": 3247359, "md5": ""c40345c1c140ea632e10931909af7423""}]}}, ""1205674.3"": {""FO203509"": [""fig|1205674.3.peg.3611""]}}',
#    'family': '"PGF_03134289"',
#    'alternate': 0,
#    'conflict': 0,
#    'viz': {'color': {'r': 153, 'g': 153, 'b': 153, 'a': 1.0},
#     'size': 10.0,
#     'position': {'x': -331.28882, 'y': 300.51288, 'z': 0.0}},
#    'label': '"hypothetical protein"',
#    'id': '60686'},
#   {'diversity': 1.0,
#    'features': '{"info": {""1682113.3"": {""CP015596"": [{"start": 438104, "end": 438171, "md5": ""4c30b25af4c8839c68f9212d01e3483a""}]}}, ""1682113.3"": {""CP015596"": [""fig|1682113.3.peg.412""]}}',
#    'family': 'PF01580',
#    'alternate': 0,
#    'conflict': 0,
#    'viz': {'color': {'r': 153, 'g': 153, 'b': 153, 'a': 1.0},
#     'size': 10.0,
#     'position': {'x': -118.38456, 'y': -492.94797, 'z': 0.0}},
#    'label': '"hypothetical protein"',
#    'id': '67153'},
#   {'diversity': 1.0,
#    'features': '{"info": {""1682113.3"": {""CP015596"": [{"start": 437927, "end": 438661, "md5": ""4c30b25af4c8839c68f9212d01e3483a""}]}}, ""1682113.3"": {""CP015596"": [""fig|1682113.3.peg.412""]}}',
#    'family': '"PGF_08225224"',
#    'alternate': 0,
#    'conflict': 0,
#    'viz': {'color': {'r': 153, 'g': 153, 'b': 153, 'a': 1.0},
#     'size': 10.0,
#     'position': {'x': -131.44846, 'y': -497.76425, 'z': 0.0}},
#    'label': '"hypothetical protein"',
#    'id': '67154'},
#   {'diversity': 1.0,
#    'features': '{"info": {""1682113.3"": {""CP015596"": [{"start": 436595, "end": 436948, "md5": ""40b5c685d90c2c67f3ad42ac5605551e""}]}}, ""1682113.3"": {""CP015596"": [""fig|1682113.3.peg.411""]}}',
#    'family': 'PF00872',
#    'alternate': 0,
#    'conflict': 0,
#    'viz': {'color': {'r': 153, 'g': 153, 'b': 153, 'a': 1.0},
#     'size': 10.0,
#     'position': {'x':
},
#   {'diversity': 1.0,
#    'features': '{"info": {""43348.9"": {""AP022606"": [{"start": 5108767, "end": 5109024, "md5": ""937ba2215e6a8d23bfd3b39a55b89119""}]}}, ""43348.9"": {""AP022606"": [""fig|43348.9.peg.5057""]}}',
#    'family': '"PGF_02891739"',
#    'alternate': 0,
#    'conflict': 0,
#    'viz': {'color': {'r': 153, 'g': 153, 'b': 153, 'a': 1.0},
#     'size': 10.0,
#     'position': {'x': 113.41079, 'y': -165.98495, 'z': 0.0}},
#    'label': '"hypothetical protein"',
#    'id': '89915'},
#   {'diversity': 1.0,
#    'features': '{"info": {""43348.9"": {""AP022606"": [{"start": 5110190, "end": 5111314, "md5": ""4bc4ab68ca79d6d7d6a9bea017ea024b""}]}}, ""43348.9"": {""AP022606"": [""fig|43348.9.peg.5061""]}}',
#    'family': '"PGF_08225224"',
#    'alternate': 0,
#    'conflict': 0,
#    'viz': {'color': {'r': 153, 'g': 153, 'b': 153, 'a': 1.0},
#     'size': 10.0,
#     'position': {'x': 537.4275, 'y': 156.40083, 'z': 0.0}},
#    'label': '"hypothetical protein"',
#    'id': '89918'},
#   {'diversity': 1.0,
#    'features': '{"info": {""43348.9"": {""AP022606"": [{"start": 5114784, "end": 5115290, "md5": ""37a5269b220be18f4fc4f68d5f11727e""}]}}, ""43348.9"": {""AP022606"": [""fig|43348.9.peg.5066""]}}',
#    'family': '"PGF_08225224"',
#    'alternate': 0,
#    'conflict': 0,
#    'viz': {'color': {'r': 153, 'g': 153, 'b': 153, 'a': 1.0},
#     'size': 10.0,
#     'position': {'x': 539.0022, 'y': 145.97003, 'z': 0.0}},
#    'label': '"hypothetical protein"',
#    'id': '89921'},
#   {'diversity': 1.0,
#    'features': '{"info": {""1389713.6"": {""CP025548"": [{"start": 60452, "end": 60862, "md5": ""9417a81205c850d8ce6913190407359b""}]}}, ""1389713.6"": {""CP025548"": [""fig|1389713.6.peg.6460""]}}',
#    'family': '"PGF_02409986"',
#    'alternate': 0,
#    'conflict': 0,
#    'viz': {'color': {'r': 153, 'g': 153, 'b': 153, 'a': 1.0},
#     'size': 10.0,
#     'position': {'x': -401.5792, 'y': -241.42284, 'z': 0.0}},
#    'label': '"Transposase-related protein"',
#    'id': '95524'},
#   {'diversity': 1.0,
#    'features': '{"info": {""1389713.6"": {""CP025548"": [{"start": 69334, "end": 69453, "md5": ""02f172a19939b3792dbaa3812ccb9542""}]}}, ""1389713.6"": {""CP025548"": [""fig|1389713.6.peg.6474""]}}',
#    'family': 'PF01797',
#    'alternate': 0,
#    'conflict': 0,
#    'viz': {'color': {'r': 153, 'g': 153, 'b': 153, 'a': 1.0},
#     'size': 10.0,
#     'position': {'x': 444.89386, 'y': 145.80423, 'z': 0.0}},
#    'label': '"transposase IS200-family protein"',
#    'id': '95535'},
#   {'diversity': 1.0,
#    'features': '{"info": {""710686.3"": {""CP003078"": [{"start": 1215372, "end": 1215475, "md5": ""377ca44a5075c00e69386d90a5c65006""}]}}, ""710686.3"": {""CP003078"": [""fig|710686.3.peg.1212""]}}',
#    'family': 'PF12680',
#    'alternate': 0,
#    'conflict': 0,
#    'viz': {'color': {'r': 153, 'g': 153, 'b': 153, 'a': 1.0},
#     'size': 10.0,
#     'position': {'x': -30.398891, 'y': 59.7516, 'z': 0.0}},
#    'label': '"Putative RNA polymerase sigma factor"',
#    'id': '96997'},
#   {'diversity': 1.0,
#    'features': '{"info": {""710686.3"": {""CP003078"": [{"start": 1217443, "end": 1217515, "md5": ""2b4def6b5a2f720a2984b88b2da7b50e""}]}}, ""710686.3"": {""CP003078"": [""fig|710686.3.peg.1215""]}}',
#    'family': 'PF13183',
#    'alternate': 0,
#    'conflict': 0,
#    'viz': {'color': {'r': 153, 'g': 153, 'b': 153, 'a': 1.0},
#     'size': 10.0,
#     'position': {'x': -30.893631, 'y': 58.782383, 'z': 0.0}},
#    'label': '"Succinate dehydrogenase iron-sulfur protein (EC 1.3.5.1)"',
#    'id': '97000'},
#   {'diversity': 1.0,
#    'features': '{"info": {""710686.3"": {""CP003078"": [{"start": 2067657, "end": 2067775, "md5": ""2fe501466410954ad93907ae14642233""}]}}, ""710686.3"": {""CP003078"": [""fig|710686.3.peg.2110""]}}',
#    'family': 'PF07729',
#    'alternate': 0,
#    'conflict': 0,
#    'viz': {'color': {'r': 153, 'g': 153, 'b': 153, 'a': 1.0},
#     'size': 10.0,
#     'position': {'x': -297.14688, 'y': -159.4387, 'z': 0.0}},
#    'label': '"Transcriptional regulator, GntR family"',
#    'id': '98195'},
#   {'diversity': 1.0,
#    'features': '{"info": {""710686.3"": {""CP003078"": [{"start": 2069742, "end": 2071235, "md5": ""29fbf323a29b4a67ae8e423087239c71""}]}}, ""710686.3"": {""CP003078"": [""fig|710686.3.peg.2112""]}}',
#    'family': '"PGF_06331417"',
#    'alternate': 0,
#    'conflict': 0,
#    'viz': {'color': {'r': 153, 'g': 153, 'b': 153, 'a': 1.0},
#     'size': 10.0,
#     'position': {'x': -319.69846, 'y': -171.69745, 'z': 0.0}},
#    'label': '"Long-chain-fatty-acid--CoA ligase (EC 6.2.1.3)"',
#    'id': '98196'},
#   {'diversity': 1.0,
#    'features': '{"info": {""710686.3"": {""CP003078"": [{"start": 2069752, "end": 2070147, "md5": ""29fbf323a29b4a67ae8e423087239c71""}]}}, ""710686.3"": {""CP003078"": [""fig|710686.3.peg.2112""]}}',
#    'family': 'PF00501',
#    'alternate': 0,
#    'conflict': 0,
#    'viz': {'color': {'r': 153, 'g': 153, 'b': 153, 'a': 1.0},
#     'size': 10.0,
#     'position': {'x': -313.44324, 'y': -160.04614, 'z': 0.0}},
#    'label': '"Long-chain-fatty-acid--CoA ligase (EC 6.2.1.3)"',
#    'id': '98197'},
#   {'diversity': 1.0,
#    'features': '{"info": {""710686.3"": {""CP003078"": [{"start": 2071241, "end": 2071622, "md5": ""b25e32b7c9102ed40e308ec6cbb999f9""}]}}, ""710686.3"": {""CP003078"": [""fig|710686.3.peg.2113""]}}',
#    'family': 'PF00501',
#    'alternate': 0,
#    'conflict': 0,
#    'viz': {'color': {'r': 153, 'g': 153, 'b': 153, 'a': 1.0},
#     'size': 10.0,
#     'position': {'x': 438.29846, 'y': -83.36366, 'z': 0.0}},
#    'label': '"Long-chain-fatty-acid--CoA ligase (EC 6.2.1.3)"',
#    'id': '98200'},
#   {'diversity': 1.0,
#    'features': '{"info": {""710686.3"": {""CP003078"": [{"start": 2073083, "end": 2073153, "md5": ""3f53704cc7f20f2f4fb460194f356842""}]}}, ""710686.3"": {""CP003078"": [""fig|710686.3.peg.2114""]}}',
#    'family': 'PF13193',
#    'alternate': 0,
#    'conflict': 0,
#    'viz': {'color': {'r': 153, 'g': 153, 'b': 153, 'a': 1.0},
#     'size': 10.0,
#     'position': {'x': -214.53548, 'y': 41.59172, 'z': 0.0}},
#    'label': '"Long-chain-fatty-acid--CoA ligase (EC 6.2.1.3)"',
#    'id': '98204'},
#   {'diversity': 1.0,
#    'features': '{"info": {""710686.3"": {""CP003078"": [{"start": 4282965, "end": 4283016, "md5": ""8afac737b71bc9e40630352f674b137f""}]}}, ""710686.3"": {""CP003078"": [""fig|710686.3.peg.4386""]}}',
#    'family': 'PF00196',
#    'alternate': 0,
#    'conflict': 0,
#    'viz': {'color': {'r': 153, 'g': 153, 'b': 153, 'a': 1.0},
#     'size': 10.0,
#     'position': {'x': -52.811817, 'y': 128.86644, 'z': 0.0}},
#    'label': '"hypothetical protein"',
#    'id': '100839'},
#   {'diversity': 1.0,
#    'features': '{"info": {""710686.3"": {""CP003078"": [{"start": 4286538, "end": 4289348, "md5": ""fe218df553356240fdd7a06651233cd7""}]}}, ""710686.3"": {""CP003078"": [""fig|710686.3.peg.4389""]}}',
#    'family': '"PGF_02393930"',
#    'alternate': 0,
#    'conflict': 0,
#    'viz': {'color': {'r': 153, 'g': 153, 'b': 153, 'a': 1.0},
#     'size': 10.0,
#     'position': {'x': -63.258247, 'y': 131.607, 'z': 0.0}},
#    'label': '"AAA-ATPase, domain of unknown function, and LuxR DNA-binding domain"',
#    'id': '100840'},
#   {'diversity': 1.0,
#    'features': '{"info": {""710686.3"": {""CP003078"": [{"start": 4286559, "end": 4286708, "md5": ""fe218df553356240fdd7a06651233cd7""}]}}, ""710686.3"": {""CP003078"": [""fig|710686.3.peg.4389""]}}',
#    'family': 'PF13191',
#    'alternate': 0,
#    'conflict': 0,
#    'viz': {'color': {'r': 153, 'g': 153, 'b': 153, 'a': 1.0},
#     'size': 10.0,
#     'position': {'x': -57.02573, 'y': 130.18388, 'z': 0.0}},
#    'label': '"AAA-ATPase, domain of unknown function, and LuxR DNA-binding domain"',
#    'id': '100841'},
#   {'diversity': 1.0,
#    'features': '{"info": {""710686.3"": {""CP003078"": [{"start": 4326540, "end": 4326689, "md5": ""532856faf7466fc962fa485377db850a""}]}}, ""710686.3"": {""CP003078"": [""fig|710686.3.peg.4417""]}}',
#    'family': 'PF13191',
#    'alternate': 0,
#    'conflict': 0,
#    'viz': {'color': {'r': 153, 'g': 153, 'b': 153, 'a': 1.0},
#     'size': 10.0,
#     'position': {'x': -405.71307, 'y': -477.10025, 'z': 0.0}},
#    'label': '"AAA-ATPase, domain of unknown function, and LuxR DNA-binding domain"',
#    'id': '100887'},
#   {'diversity': 1.0,
#    'features': '{"info": {""710686.3"": {""CP003078"": [{"start": 4329960, "end": 4330109, "md5": ""48b61e514633e57b3cb27e1926c853a2""}]}}, ""710686.3"": {""CP003078"": [""fig|710686.3.peg.4420""]}}',
#    'family': '"PGF_03162928"',
#    'alternate': 0,
#    'conflict': 0,
#    'viz': {'color': {'r': 153, 'g': 153, 'b': 153, 'a': 1.0},
#     'size': 10.0,
#     'position': {'x': -416.75836, 'y': -517.339, 'z': 0.0}},
#    'label': '"hypothetical protein"',
#    'id': '100888'},
#   {'diversity': 1.0,
#    'features': '{"info": {""710686.3"": {""CP003078"": [{"start": 4330168, "end": 4330920, "md5": ""9cae937c53da40a663744c7b359c355e""}]}}, ""710686.3"": {""CP003078"": [""fig|710686.3.peg.4421""]}}',
#    'family': '"PGF_04139721"',
#    'alternate': 0,
#    'conflict': 0,
#    'viz': {'color': {'r': 153, 'g': 153, 'b': 153, 'a': 1.0},
#     'size': 10.0,
#     'position': {'x': -409.6839, 'y': -481.45682, 'z': 0.0}},
#    'label': '"Enoyl-CoA hydratase (EC 4.2.1.17)"',
#    'id': '100889'},
#   {'diversity': 1.0,
# ...
#    'id': '149142',
#    'weight': 0.021276595,
#    'source': '103477',
#    'target': '103476'},
#   {'genomes': '"710686.3"',
#    'sequences': '"CP003080"',
#    'id': '149716',
#    'weight': 0.021276595,
#    'source': '104064',
#    'target': '104065'},
#   {'genomes': '"710686.3"',
#    'sequences': '"CP003080"',
#    'id': '149715',
#    'weight': 0.021276595,
#    'source': '104064',
#    'target': '104063'},
#   {'genomes': '"439334.465"',
#    'sequences': '"AP020326"',
#    'id': '110532',
#    'weight': 0.021276595,
#    'source': '54751',
#    'target': '54750'},
#   {'genomes': '"710686.3"',
#    'sequences': '"CP003078"',
#    'id': '145445',
#    'weight': 0.021276595,
#    'source': '99379',
#    'target': '99378'},
#   {'genomes': '"44010.9"',
#    'sequences': '"AP022613"',
#    'id': '161307',
#    'weight': 0.021276595,
#    'source': '119325',
#    'target': '119326'},
#   {'genomes': '"44010.9"',
#    'sequences': '"AP022613"',
#    'id': '73184',
#    'weight': 0.021276595,
#    'source': '119325',
#    'target': '27786'},
#   {'genomes': '"120959.23"',
#    'sequences': '"CP045075"',
#    'id': '154932',
#    'weight': 0.021276595,
#    'source': '110990',
#    'target': '110989'},
#   {'genomes': '"120959.23"',
#    'sequences': '"CP045075"',
#    'id': '154934',
#    'weight': 0.021276595,
#    'source': '110993',
#    'target': '110992'},
#   {'genomes': '"120959.23"',
#    'sequences': '"CP045075"',
#    'id': '65716',
#    'weight': 0.021276595,
#    'source': '110993',
#    'target': '23479'},
#   {'genomes': '"1136880.4"',
#    'sequences': '"AP018410"',
#    'id': '103261',
#    'weight': 0.021276595,
#    'source': '48930',
#    'target': '48931'},
#   {'genomes': '"1136880.4"',
#    'sequences': '"AP018410"',
#    'id': '64622',
#    'weight': 0.021276595,
#    'source': '48930',
#    'target': '22992'},
#   {'genomes': '"1136880.4"',
#    'sequences': '"AP018410"',
#    'id': '103262',
#    'weight': 0.021276595,
#    'source': '48931',
#    'target': '48932'},
#   {'genomes': '"1136880.4"',
#    'sequences': '"AP018410"',
#    'id': '103263',
#    'weight': 0.021276595,
#    'source': '48932',
#    'target': '80176'},
#   {'genomes': '"1136880.4"',
#    'sequences': '"AP018410"',
#    'id': '64618',
#    'weight': 0.021276595,
#    'source': '80176',
#    'target': '22991'},
#   {'genomes': '"1809.14"',
#    'sequences': '"LR135168"',
#    'id': '118948',
#    'weight': 0.021276595,
#    'source': '66157',
#    'target': '66158'},
#   {'genomes': '"1809.14"',
#    'sequences': '"LR135168"',
#    'id': '8069',
#    'weight': 0.021276595,
#    'source': '66157',
#    'target': '2281'},
#   {'genomes': '"1809.14"',
#    'sequences': '"LR135168"',
#    'id': '118949',
#    'weight': 0.021276595,
#    'source': '66158',
#    'target': '66159'},
#   {'genomes': '"1809.14"',
#    'sequences': '"LR135168"',
#    'id': '118950',
#    'weight': 0.021276595,
#    'source': '66159',
#    'target': '66160'},
#   {'genomes': '"560555.10"',
#    'sequences': '"AP022590"',
#    'id': '159625',
#    'weight': 0.021276595,
#    'source': '117142',
#    'target': '117143'},
#   {'genomes': '"560555.10"',
#    'sequences': '"AP022590"',
#    'id': '86998',
#    'weight': 0.021276595,
#    'source': '117142',
#    'target': '36972'},
#   {'genomes': '"560555.10"',
#    'sequences': '"AP022590"',
#    'id': '40609',
#    'weight': 0.021276595,
#    'source': '117143',
#    'target': '12765'},
#   {'genomes': '"710686.3"',
#    'sequences': '"CP003079"',
#    'id': '149484',
#    'weight': 0.021276595,
#    'source': '103829',
#    'target': '103831'},
#   {'genomes': '"710686.3"',
#    'sequences': '"CP003078"',
#    'id': '144125',
#    'weight': 0.021276595,
#    'source': '97900',
#    'target': '97901'},
#   {'genomes': '"710686.3"',
#    'sequences': '"CP003078"',
#    'id': '144126',
#    'weight': 0.021276595,
#    'source': '97900',
#    'target': '97903'},
#   {'genomes': '"710686.3"',
#    'sequences': '"CP003078"',
#    'id': '144128',
#    'weight': 0.021276595,
#    'source': '97903',
#    'target': '97904'},
#   {'genomes': '"710686.3"',
#    'sequences': '"CP003078"',
#    'id': '144129',
#    'weight': 0.021276595,
#    'source': '97904',
#    'target': '97905'},
#   {'genomes': '"710686.3"',
#    'sequences': '"CP003078"',
#    'id': '144130',
#    'weight': 0.021276595,
#    'source': '97905',
#    'target': '97906'},
#   {'genomes': '"710686.3"',
#    'sequences': '"CP003078"',
#    'id': '144131',
#    'weight': 0.021276595,
#    'source': '97906',
#    'target': '97907'},
#   {'genomes': '"710686.3"',
#    'sequences': '"CP003078"',
#    'id': '144132',
#    'weight': 0.021276595,
#    'source': '97907',
#    'target': '97908'},
#   {'genomes': '"710686.3"',
#    'sequences': '"CP003078"',
#    'id': '144133',
#    'weight': 0.021276595,
#    'source': '97908',
#    'target': '97909'},
#   {'genomes': '"710686.3"',
#    'sequences': '"CP003078"',
#    'id': '144134',
#    'weight': 0.021276595,
#    'source': '97909',
#    'target': '97910'},
#   {'genomes': '"710686.3"',
#    'sequences': '"CP003078"',
#    'id': '144135',
#    'weight': 0.021276595,
#    'source': '97910',
#    'target': '97911'},
#   {'genomes': '"710686.3"',
#    'sequences': '"CP003078"',
#    'id': '144136',
#    'weight': 0.021276595,
#    'source': '97911',
#    'target': '97912'},
#   {'genomes': '"710686.3"',
#    'sequences': '"CP003078"',
#    'id': '144137',
#    'weight': 0.021276595,
#    'source': '97912',
#    'target': '97914'},
#   {'genomes': '"710686.3"',
#    'sequences': '"CP003078"',
#    'id': '144138',
#    'weight': 0.021276595,
#    'source': '97913',
#    'target': '97914'},
#   {'genomes': '"710686.3"',
#    'sequences': '"CP003078"',
#    'id': '144139',
#    'weight': 0.021276595,
#    'source': '97913',
#    'target': '97915'},
#   {'genomes': '"710686.3"',
#    'sequences': '"CP003078"',
#    'id': '144144',
#    'weight': 0.021276595,
#    'source': '97918',
#    'target': '97919'},
#   {'genomes': '"710686.3"',
#    'sequences': '"CP003078"',
#    'id': '144143',
#    'weight': 0.021276595,
#    'source': '97918',
#    'target': '97920'},
#   {'genomes': '"710686.3"',
#    'sequences': '"CP003078"',
#    'id': '144145',
#    'weight': 0.021276595,
#    'source': '97920',
#    'target': '97921'},
#   {'genomes': '"710686.3"',
#    'sequences': '"CP003078"',
#    'id': '144146',
#    'weight': 0.021276595,
#    'source': '97921',
#    'target': '97922'},
#   {'genomes': '"710686.3"',
#    'sequences': '"CP003078"',
#    'id': '144147',
#    'weight': 0.021276595,
#    'source': '97922',
#    'target': '97923'},
#   {'genomes': '"710686.3"',
#    'sequences': '"CP003078"',
#    'id': '144140',
#    'weight': 0.021276595,
#    'source': '97915',
#    'target': '97916'},
#   {'genomes': '"710686.3"',
#    'sequences': '"CP003078"',
#    'id': '144141',
#    'weight': 0.021276595,
#    'source': '97916',
#    'target': '97917'},
#   {'genomes': '"710686.3"',
#    'sequences': '"CP003078"',
#    'id': '144142',
#    'weight': 0.021276595,
#    'source': '97917',
#    'target': '97919'},
#   {'genomes': '"710686.3"',
#    'sequences': '"CP003078"',
#    'id': '144148',
#    'weight': 0.021276595,
#    'source': '97923',
#    'target': '97924'},
#   {'genomes': '"710686.3"',
#    'sequences': '"CP003078"',
#    'id': '144149',
#    'weight': 0.021276595,
#    'source': '97924',
#    'target': '97925'},
#   {'genomes': '"710686.3"',
#    'sequences': '"CP003078"',
#    'id': '144150',
#    'weight': 0.021276595,
#    'source': '97925',
#    'target': '97926'},
#   {'genomes': '"710686.3"',
#    'sequences': '"CP003078"',
#    'id': '144151',
#    'weight': 0.021276595,
#    'source': '97926',
#    'target': '97927'},
#   {'genomes': '"710686.3"',
#    'sequences': '"CP003078"',
#    'id': '144152',
#    'weight': 0.021276595,
#    'source': '97927',
#    'target': '97928'},
#   {'genomes': '"710686.3"',
#    'sequences': '"CP003078"',
#    'id': '144153',
#    'weight': 0.021276595,
#    'source': '97928',
#    'target': '97929'},
#   {'genomes': '"710686.3"',
#    'sequences': '"CP003078"',
#    'id': '144154',
#    'weight': 0.021276595,
#    'source': '97929',
#    'target': '97930'},
#   {'genomes': '"710686.3"',
#    'sequences': '"CP003078"',
#    'id': '144160',
#    'weight': 0.021276595,
#    'source': '97936',
#    'target': '97937'},
#   {'genomes': '"710686.3"',
#    'sequences': '"CP003078"',
#    'id': '144161',
#    'weight': 0.021276595,
#    'source': '97936',
#    'target': '97940'},
#   {'genomes': '"710686.3"',
#    'sequences': '"CP003078"',
#    'id': '144162',
#    'weight': 0.021276595,
#    'source': '97937',
#    'target': '97938'},
#   {'genomes': '"710686.3"',
#    'sequences': '"CP003078"',
#    'id': '144163',
#    'weight': 0.021276595,
#    'source': '97938',
#    'target': '97939'},
#   {'genomes': '"710686.3"',
#    'sequences': '"CP003078"',
#    'id': '144164',
#    'weight': 0.021276595,
#    'source': '97940',
#    'target': '97941'},
#   {'genomes': '"710686.3"',
#    'sequences': '"CP003078"',
#    'id': '144165',
#    'weight': 0.021276595,
#    'source': '97941',
#    'target': '97942'},
#   {'genomes': '"710686.3"',
#    'sequences': '"CP003078"',
#    'id': '144166',
#    'weight': 0.021276595,
#    'source': '97942',
#    'target': '97943'},
#   {'genomes': '"710686.3"',
#    'sequences': '"CP003078"',
#    'id': '144167',
#    'weight': 0.021276595,
#    'source': '97943',
#    'target': '97944'},
#   {'genomes': '"710686.3"',
#    'sequences': '"CP003078"',
#    'id': '144168',
#    'weight': 0.021276595,
#    'source': '97944',
#    'target': '97945'},
#   {'genomes': '"710686.3"',
#    'sequences': '"CP003078"',
#    'id': '144169',
#    'weight': 0.021276595,
#    'source': '97945',
#    'target': '97946'},
#   {'genomes': '"710686.3"',
#    'sequences': '"CP003078"',
#    'id': '144170',
#    'weight': 0.021276595,
#    'source': '97946',
#    'target': '97947'},
#   {'genomes': '"710686.3"',
#    'sequences': '"CP003078"',
#    'id': '144171',
#    'weight': 0.021276595,
#    'source': '97947',
#    'target': '97948'},
#   {'genomes': '"710686.3"',
#    'sequences': '"CP003078"',
#    'id': '144172',
#    'weight': 0.021276595,
#    'source': '97948',
#    'target': '97949'},
#   {'genomes': '"710686.3"',
#    'sequences': '"CP003078"',
#    'id': '144173',
#    'weight': 0.021276595,
#    'source': '97949',
#    'target': '97950'},
#   {'genomes': '"710686.3"',
#    'sequences': '"CP003078"',
#    'id': '144174',
#    'weight': 0.021276595,
#    'source': '97950',
#    'target': '97951'},
#   {'genomes': '"710686.3"',
#    'sequences': '"CP003078"',
#    'id': '144175',
#    'weight': 0.021276595,
#    'source': '97951',
#    'target': '97952'},
#   {'genomes': '"710686.3"',
#    'sequences': '"CP003078"',
#    'id': '144176',
#    'weight': 0.021276595,
#    'source': '97952',
#    'target': '97953'},
#   {'genomes': '"710686.3"',
#    'sequences': '"CP003078"',
#    'id': '144177',
#    'weight': 0.021276595,
#    'source': '97953',
#    'target': '97954'},
#   {'genomes': '"710686.3"',
#    'sequences': '"CP003078"',
#    'id': '144178',
#    'weight': 0.021276595,
#    'source': '97954',
#    'target': '97955'},
#   {'genomes': '"710686.3"',
#    'sequences': '"CP003078"',
#    'id': '144179',
#    'weight': 0.021276595,
#    'source': '97955',
#    'target': '97956'},
#   {'genomes': '"710686.3"',
#    'sequences': '"CP003078"',
#    'id': '144180',
#    'weight': 0.021276595,
#    'source': '97956',
#    'target': '97957'},
#   {'genomes': '"710686.3"',
#    'sequences': '"CP003078"',
#    'id': '144181',
#    'weight': 0.021276595,
#    'source': '97957',
#    'target': '97958'},
#   {'genomes': '"710686.3"',
#    'sequences': '"CP003078"',
#    'id': '144182',
#    'weight': 0.021276595,
#    'source': '97958',
#    'target': '97959'},
#   {'genomes': '"710686.3"',
#    'sequences': '"CP003078"',
#    'id': '144183',
#    'weight': 0.021276595,
#    'source': '97959',
#    'target': '97960'},
#   {'genomes': '"710686.3"',
#    'sequences': '"CP003078"',
#    'id': '144184',
#    'weight': 0.021276595,
#    'source': '97960',
#    'target': '97961'},
#   {'genomes': '"710686.3"',
#    'sequences': '"CP003078"',
#    'id': '144185',
#    'weight': 0.021276595,
#    'source': '97961',
#    'target': '97962'},
#   {'genomes': '"710686.3"',
#    'sequences': '"CP003078"',
#    'id': '144186',
#    'weight': 0.021276595,
#    'source': '97962',
#    'target': '97963'},
#   {'genomes': '"710686.3"',
#    'sequences': '"CP003078"',
#    'id': '144187',
#    'weight': 0.021276595,
#    'source': '97963',
#    'target': '97964'},
#   {'genomes': '"710686.3"',
#    'sequences': '"CP003078"',
#    'id': '144188',
#    'weight': 0.021276595,
#    'source': '97964',
#    'target': '97965'},
#   {'genomes': '"710686.3"',
#    'sequences': '"CP003078"',
#    'id': '144189',
#    'weight': 0.021276595,
#    'source': '97965',
#    'target': '97966'},
#   {'genomes': '"710686.3"',
#    'sequences': '"CP003078"',
#    'id': '144190',
#    'weight': 0.021276595,
#    'source': '97966',
#    'target': '97967'},
#   {'genomes': '"710686.3"',
#    'sequences': '"CP003079"',
#    'id': '149024',
#    'weight': 0.021276595,
#    'source': '103358',
#    'target': '103357'},
#   {'genomes': '"710686.3"',
#    'sequences': '"CP003079"',
#    'id': '149141',
#    'weight': 0.021276595,
#    'source': '103475',
#    'target': '103476'},
#   {'genomes': '"710686.3"',
#    'sequences': '"CP003079"',
#    'id': '149140',
#    'weight': 0.021276595,
#    'source': '103475',
#    'target': '103474'},
#   {'genomes': '"710686.3"',
#    'sequences': '"CP003080"',
#    'id': '149712',
#    'weight': 0.021276595,
#    'source': '104060',
#    'target': '104061'},
#   {'genomes': '"710686.3"',
#    'sequences': '"CP003080"',
#    'id': '149711',
#    'weight': 0.021276595,
#    'source': '104060',
#    'target': '104059'},
#   {'genomes': '"710686.3"',
#    'sequences': '"CP003080"',
#    'id': '149713',
#    'weight': 0.021276595,
#    'source': '104061',
#    'target': '104062'},
#   {'genomes': '"710686.3"',
#    'sequences': '"CP003080"',
#    'id': '149714',
#    'weight': 0.021276595,
#    'source': '104062',
#    'target': '104063'},
#   {'genomes': '"185642.10"',
#    'sequences': '"AP022614"',
#    'weight': 0.021276595,
#    'source': '127177',
#    'target': '786'},
#   {'genomes': '"185642.10"',
#    'sequences': '"AP022614"',
#    'weight': 0.021276595,
#    'source': '127177',
#    'target': '787'},
#   {'genomes': '"43348.9"',
#    'sequences': '"AP022606"',
#    'id': '136549',
#    'weight': 0.021276595,
#    'source': '88538',
#    'target': '88537'},
#   {'genomes': '"43348.9"',
#    'sequences': '"AP022606"',
#    'weight': 0.021276595,
#    'source': '88538',
#    'target': '786'},
#   {'genomes': '"1789.10"',
#    'sequences': '"AP022314"',
#    'id': '152625',
#    'weight': 0.021276595,
#    'source': '107732',
#    'target': '107733'},
#   {'genomes': '"1789.10"',
#    'sequences': '"AP022314"',
#    'id': '25226',
#    'weight': 0.021276595,
#    'source': '107732',
#    'target': '7289'},
#   {'genomes': '"1789.10"',
#    'sequences': '"AP022314"',
#    'id': '25212',
#    'weight': 0.021276595,
#    'source': '107733',
#    'target': '7287'},
#   {'genomes': '"1809.14","1124626.4"',
#    'sequences': '"LR135168","AP017635"',
#    'id': '91432',
#    'weight': 0.04255319,
#    'source': '40364',
#    'target': '40365'},
#   {'genomes': '"1809.14","1124626.4"',
#    'sequences': '"LR135168","AP017635"',
#    'id': '25216',
#    'weight': 0.04255319,
#    'source': '40364',
#    'target': '7288'},
#   {'genomes': '"1809.14","1124626.4"',
#    'sequences': '"LR135168","AP017635"',
#    'id': '91433',
#    'weight': 0.04255319,
#    'source': '40365',
#    'target': '40366'},
#   {'genomes': '"1809.14","1124626.4"',
#    'sequences': '"LR135168","AP017635"',
#    'id': '91434',
#    'weight': 0.04255319,
#    'source': '40366',
#    'target': '40367'},
#   {'genomes': '"1809.14","1124626.4"',
#    'sequences': '"LR135168","AP017635"',
#    'id': '25211',
#    'weight': 0.04255319,
#    'source': '40367',
#    'target': '7287'},
#   {'genomes': '"710686.3"',
#    'sequences': '"CP003078"',
#    'id': '145444',
#    'weight': 0.021276595,
#    'source': '99377',
#    'target': '99378'},
#   {'genomes': '"710686.3"',
#    'sequences': '"CP003078"',
#    'id': '50629',
#    'weight': 0.021276595,
#    'source': '99377',
#    'target': '16745'},
#   {'genomes': '"1809.14"',
#    'sequences': '"LR135168"',
#    'id': '118918',
#    'weight': 0.021276595,
#    'source': '66112',
#    'target': '66113'},
#   {'genomes': '"1809.14"',
#    'sequences': '"LR135168"',
#    'id': '118917',
#    'weight': 0.021276595,
#    'source': '66112',
#    'target': '66111'},
#   {'genomes': '"1809.14"',
#    'sequences': '"LR135168"',
#    'id': '86043',
#    'weight': 0.021276595,
#    'source': '66113',
#    'target': '36316'},
#   {'genomes': '"1775.8"',
#    'sequences': '"AP022569"',
#    'id': '125108',
#    'weight': 0.021276595,
#    'source': '73996',
#    'target': '73997'},
#   ...]}
